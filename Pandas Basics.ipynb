# %% [markdown]
# <a href="https://colab.research.google.com/github/Anagha-dsa/Data.science/blob/main/pandas_assignmnt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Do the following operation on Iris dataset:
#
# 1. Read the dataset to python environment.
# 2. Display the columns in the dataset.
# 3. Calculate the mean of each column of the dataset.
# 4. Check for the null values present in the dataset.
# 5. Perform meaningful visualizations using the dataset. Bring at least 3
# visualizations.

# %%
import pandas as pd

data=pd.read_excel('/content/iris.xls')
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #**`Diplaying the columns of data sheet`**

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # **Calculating the mean of each column of the dataset.**

# %%
# Calculating the mean of each column of the dataset

data.describe()
# Out:
#                SL          SW          PL          PW
# count  150.000000  150.000000  150.000000  150.000000
# mean     0.000178    3.054000    3.758667    1.198667
# std      0.000025    0.433594    1.764420    0.763161
# min      0.000131    2.000000    1.000000    0.100000
# 25%      0.000156    2.800000    1.600000    0.300000
# 50%      0.000177    3.000000    4.350000    1.300000
# 75%      0.000195    3.300000    5.100000    1.800000
# max      0.000241    4.400000    6.900000    2.500000

# %% [markdown]
# # **Checking for the null values present in the dataset**

# %%
data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # **Data visualisation**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **Multiple charts**

# %%
fig=plt.figure(figsize=(14,7))
plt.subplot(1,3,1)
plt.plot(data['SL'],data['SW'],color='green')
plt.xlabel('SL')
plt.ylabel('SW')
plt.title('Line chart')


plt.subplot(1,3,2)
plt.bar(data['PW'],data['PL'],width=0.08)
plt.grid(True)
plt.title('bar chart')


plt.subplot(1,3,3)
plt.scatter(data['SL'],data['SW'],linewidths=0.5,color='red')
plt.title('Scatter chart')


plt.suptitle("Multiple Charts");

# %% [markdown]
# # **Box plot**

# %%
plt.boxplot(data['SW'])
plt.title('Box Plot');

# %% [markdown]
# # **Line chart**

# %%
bar_width = (max(data['SL']) - min(data['SL'])) / len(data['SL'])

plt.bar(data['SL'],data['SW'],width=bar_width,color='green')
plt.xlabel('SL')
plt.ylabel('SW')
plt.grid(True)
plt.title('Line chart ');

# %%
plt.hist(data['SL'], bins=9, edgecolor='black')
plt.xlabel('SL')
plt.ylabel('Frequency')
plt.title('Distribution of SL')
plt.show()
